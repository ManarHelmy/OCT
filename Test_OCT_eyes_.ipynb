# %% [markdown]
# <a href="https://colab.research.google.com/github/ManarHelmy/OCT/blob/main/Test_OCT_eyes_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import numpy as np
import cv2
from keras.models import load_model
from google.colab import files
import matplotlib.pyplot as plt

# Preprocess the image
def preprocess_image(image_path):
    img = cv2.imread(image_path)
    img = cv2.resize(img, (224, 224))  # Resize to match model input
    img = img / 255.0  # Normalize the image
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# Load the pre-trained model
model = load_model('/content/oct_model.h5')  # Update with the correct model path
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Preprocess the uploaded image
processed_img = preprocess_image('/content/cnv.jpg')
# Make predictions
predictions = model.predict(processed_img)
predicted_class = np.argmax(predictions, axis=1)
classes = {0 : 'CNV',
           1 : 'DME',
           2 : 'Drusen',
           3 : 'Normal'}
# Visualize the image and prediction
plt.imshow(processed_img[0], cmap='gray')
print("Predicted: Class ",predicted_class[0],": ",classes[predicted_class[0]],sep='') # Access the first element of predicted_class, which is the actual class index
# Modified to provide a single string
plt.title(f"Prediction: {classes[predicted_class[0]]}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Predicted: Class 0: CNV

# %%
# Preprocess the uploaded image
processed_img = preprocess_image('/content/dme.jpg')
# Make predictions
predictions = model.predict(processed_img)
predicted_class = np.argmax(predictions, axis=1)
classes = {0 : 'CNV',
           1 : 'DME',
           2 : 'Drusen',
           3 : 'Normal'}
# Visualize the image and prediction
plt.imshow(processed_img[0], cmap='gray')
print("Predicted: Class ",predicted_class[0],": ",classes[predicted_class[0]],sep='') # Access the first element of predicted_class, which is the actual class index
# Modified to provide a single string
plt.title(f"Prediction: {classes[predicted_class[0]]}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Predicted: Class 1: DME

# %%
# Preprocess the uploaded image
processed_img = preprocess_image('/content/drusen.jpg')
# Make predictions
predictions = model.predict(processed_img)
predicted_class = np.argmax(predictions, axis=1)
classes = {0 : 'CNV',
           1 : 'DME',
           2 : 'Drusen',
           3 : 'Normal'}
# Visualize the image and prediction
plt.imshow(processed_img[0], cmap='gray')
print("Predicted: Class ",predicted_class[0],": ",classes[predicted_class[0]],sep='') # Access the first element of predicted_class, which is the actual class index
# Modified to provide a single string
plt.title(f"Prediction: {classes[predicted_class[0]]}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Predicted: Class 2: Drusen

# %%
# Preprocess the uploaded image
processed_img = preprocess_image('/content/normal.jpg')
# Make predictions
predictions = model.predict(processed_img)
predicted_class = np.argmax(predictions, axis=1)
classes = {0 : 'CNV',
           1 : 'DME',
           2 : 'Drusen',
           3 : 'Normal'}
# Visualize the image and prediction
plt.imshow(processed_img[0], cmap='gray')
print("Predicted: Class ",predicted_class[0],": ",classes[predicted_class[0]],sep='') # Access the first element of predicted_class, which is the actual class index
# Modified to provide a single string
plt.title(f"Prediction: {classes[predicted_class[0]]}")
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Predicted: Class 3: Normal
